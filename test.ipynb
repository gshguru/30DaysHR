# %% [markdown]
# <iframe width="800" height="500" frameborder="0"
#         src="http://pythontutor.com/iframe-embed.html#code=x+%3D+5%0Ay+%3D+10%0Az+%3D+x+%2B+y&cumulative=false&py=2&curInstr=3">
# </iframe>

# %%
from IPython.display import IFrame

# %%
IFrame('http://pythontutor.com/iframe-embed.html#code=class+Person%3A%0A%0A++++def+__init__(self,+initial_Age%29%3A%0A++++++++if+initial_Age+%3C+0%3A%0A++++++++++++print(%22This+person+is+not+valid,+setting+age+to+0.%22%29%0A++++++++++++self.age+%3D+0%0A++++++++else%3A%0A++++++++++++self.age+%3D+initial_Age%0A%0A++++def+amIOld(self%29%3A%0A++++++++if+self.age+%3C+13%3A%0A++++++++++++print(%22You+are+young.%22%29%0A++++++++elif+self.age+%3E%3D+13+and+self.age+%3C+18%3A%0A++++++++++++print(%22You+are+a+teenager.%22%29%0A++++++++else%3A%0A++++++++++++print(%22You+are+old.%22%29%0A%0A++++def+yearPasses(self%29%3A%0A++++++++self.age+%2B%3D+1%0A%0AT%3Dint(raw_input(%29%29%0Afor+i+in+range(0,T%29%3A%0A++++age%3Dint(raw_input(%29%29+++++++++%0A++++p%3DPerson(age%29++%0A++++p.amIOld(%29%0A++++for+j+in+range(0,3%29%3A%0A++++++++p.yearPasses(%29%3B++++++++%0A++++p.amIOld(%29%3B%0A++++print+%22%22&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&py=2&rawInputLstJSON=%5B%222%22,%220%22,%2217%22%5D&curInstr=73&testCasesJSON=%5B%222%5Cn3%5Cn12%22%5D&codeDivWidth=600&codeDivHeight=700', width=700, height=1000)
# Out:
#         <iframe
#             width="700"
#             height="1000"
# ...

# %% [markdown]
# <iframe width="420" height="315" src="http://www.youtube.com/embed/dQw4w9WgXcQ" frameborder="0" allowfullscreen></iframe>
